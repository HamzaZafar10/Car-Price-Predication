# %% [markdown]
# 1) All libraries

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import joblib

# %% [markdown]
# 2) To connect Google drive with colab for csv file

# %%
data =pd.read_csv('/content/CAR model.csv')

# %% [markdown]
# 3) Top 5 Rows of Dataset

# %%
data.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %% [markdown]
# 4) Last 5 Row of Dataset

# %%
data.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %% [markdown]
#  5) Find Shape of Dataset Number of Rows And Number of Columns

# %%
data.shape
# Out:
# (4340, 8)

# %% [markdown]
# 6) Information About Dataset Like the Total Number of Rows, Total Number of Columns, Data types of Each Column

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %% [markdown]
# 7) Check Null Values In The Dataset

# %%
data.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %% [markdown]
# 8) Get Overall Statistics About The Dataset

# %%
data.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %% [markdown]
# 9) Data Preprocessing

# %%
date_time = datetime.datetime.now()
data['Age']=date_time.year - data['year']

# %%
data.head(5)
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner  Age
# 0  Individual       Manual   First Owner   17
# 1  Individual       Manual   First Owner   17
# 2  Individual       Manual   First Owner   12
# 3  Individual       Manual   First Owner    7
# 4  Individual       Manual  Second Owner   10

# %%
data.drop('year',axis=1,inplace=True)

# %% [markdown]
# 10) Outlier Removal

# %%
sns.boxplot(x=data['selling_price'])
plt.gca().xaxis.set_major_formatter(plt.matplotlib.ticker.StrMethodFormatter("{x:,.0f}"))

# %%
sorted(data['selling_price'],reverse=True)
# Out:
# [8900000,
#  8150000,
#  5500000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4950000,
#  4800000,
#  4800000,
#  4700000,
#  4500000,
#  4500000,
#  4500000,
#  4400000,
#  4400000,
#  4200000,
#  4000000,
#  4000000,
#  4000000,
#  3899000,
#  3899000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3800000,
#  3500000,
#  3500000,
#  3256000,
#  3200000,
#  3200000,
#  3200000,
#  3100000,
#  3100000,
#  3100000,
#  3050000,
#  2900000,
#  2900000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2750000,
#  2750000,
#  2750000,
#  2750000,
#  2700000,
#  2700000,
#  2700000,
#  2700000,
#  2675000,
#  2675000,
#  2650000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2600000,
#  2595000,
#  2575000,
#  2550000,
#  2500000,
#  2500000,
#  2500000,
#  2500000,
#  2490000,
#  2400000,
#  2349000,
#  2300000,
#  2300000,
#  2200000,
#  2150000,
#  2100000,
#  2050000,
#  2050000,
#  2000000,
#  2000000,
#  2000000,
#  2000000,
#  1975000,
#  1964999,
#  1950000,
#  1900000,
#  1900000,
#  1900000,
#  1900000,
#  1900000,
#  1860000,
#  1850000,
#  1850000,
#  1850000,
#  1825000,
#  1800000,
#  1800000,
#  1800000,
#  1800000,
#  1800000,
#  1800000,
#  1800000,
#  1770000,
#  1770000,
#  1750000,
#  1750000,
#  1750000,
#  1750000,
#  1750000,
#  1735000,
#  1725000,
#  1725000,
#  1700000,
#  1700000,
#  1700000,
#  1700000,
#  1700000,
#  1700000,
#  1700000,
#  1680000,
#  1650000,
#  1650000,
#  1650000,
#  1650000,
#  1600000,
#  1600000,
#  1600000,
#  1580000,
#  1580000,
#  1580000,
#  1580000,
#  1580000,
#  1580000,
#  1580000,
#  1580000,
#  1580000,
#  1580000,
#  1580000,
#  1580000,
#  1575000,
#  1550000,
#  1549000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1490000,
#  1490000,
#  1490000,
#  1490000,
#  1485000,
#  1475000,
#  1475000,
#  1470000,
#  1470000,
#  1451000,
#  1450000,
#  1425000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1380000,
#  1375000,
#  1375000,
#  1350000,
#  1350000,
#  1350000,
#  1350000,
#  1350000,
#  1350000,
#  1350000,
#  1334000,
#  1331000,
#  1330000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1295000,
#  1295000,
#  1290000,
#  1280000,
#  1260000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1249000,
#  1249000,
#  1240000,
#  1230000,
#  1225000,
#  1225000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1199000,
#  1195000,
#  1190000,
#  1189000,
#  1165000,
#  1151000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1140000,
#  1125000,
#  1119000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1090000,
#  1085000,
#  1085000,
#  1075000,
#  1068000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1044999,
#  1044999,
#  1040000,
#  1035000,
#  1030000,
#  1030000,
#  1025000,
#  1025000,
#  1025000,
#  1025000,
#  1025000,
#  1025000,
#  1015000,
#  1010000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  999000,
#  999000,
#  990000,
#  980000,
#  980000,
#  975000,
#  975000,
#  969999,
#  969999,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  940000,
#  940000,
#  940000,
#  940000,
#  940000,
#  940000,
#  936999,
#  930000,
#  930000,
#  930000,
#  930000,
#  930000,
#  927999,
#  925000,
#  925000,
#  925000,
#  925000,
#  925000,
#  925000,
#  925000,
#  925000,
#  925000,
#  919999,
#  919999,
#  910000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  894999,
#  894999,
#  890000,
#  890000,
#  890000,
#  890000,
#  890000,
#  890000,
#  890000,
#  890000,
#  890000,
#  880000,
#  880000,
#  880000,
#  875000,
#  875000,
#  875000,
#  875000,
#  875000,
#  869999,
#  869999,
#  869999,
#  865000,
#  861999,
#  860000,
#  860000,
#  860000,
#  860000,
#  852000,
#  851000,
#  851000,
#  851000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  844999,
#  844999,
#  841000,
#  840000,
#  840000,
#  840000,
#  840000,
#  840000,
#  836000,
#  836000,
#  835000,
#  830000,
#  830000,
#  830000,
#  830000,
#  828999,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  821000,
#  819999,
#  819999,
#  819999,
#  819999,
#  815000,
#  811999,
#  810000,
#  802000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  799000,
#  795000,
#  795000,
#  790000,
#  790000,
#  790000,
#  790000,
#  790000,
#  790000,
#  790000,
#  790000,
#  790000,
#  790000,
#  785000,
#  785000,
#  784000,
#  784000,
#  782000,
#  782000,
#  780000,
#  780000,
#  780000,
#  780000,
#  780000,
#  780000,
#  780000,
#  780000,
#  780000,
#  775000,
#  775000,
#  775000,
#  775000,
#  775000,
#  774000,
#  770000,
#  770000,
#  770000,
#  765000,
#  763000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  755000,
#  751000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  749000,
#  746000,
#  744000,
#  740000,
#  740000,
#  740000,
#  740000,
#  738000,
#  735000,
#  735000,
#  735000,
#  730000,
#  730000,
#  730000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  724000,
#  721000,
#  720000,
#  720000,
#  720000,
#  720000,
#  720000,
#  720000,
#  716000,
#  715000,
#  715000,
#  715000,
#  715000,
#  715000,
#  715000,
#  711000,
#  711000,
#  711000,
#  711000,
#  710000,
#  710000,
#  710000,
#  707000,
#  701000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  699000,
#  699000,
#  699000,
#  696000,
#  695000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  685000,
#  685000,
#  685000,
#  685000,
#  685000,
#  680000,
#  680000,
#  680000,
#  680000,
#  680000,
#  680000,
#  680000,
#  680000,
#  680000,
#  680000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  670000,
#  670000,
#  670000,
#  670000,
#  670000,
#  670000,
#  670000,
#  670000,
#  670000,
#  670000,
#  670000,
#  670000,
#  670000,
#  670000,
#  670000,
#  665000,
#  665000,
#  665000,
#  665000,
#  665000,
#  665000,
#  665000,
#  660000,
#  660000,
#  660000,
#  660000,
#  660000,
#  660000,
#  655000,
#  655000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  641000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  639000,
#  635000,
#  635000,
#  635000,
#  630000,
#  630000,
#  630000,
#  630000,
#  630000,
#  630000,
#  630000,
#  630000,
#  ...]

# %%
data[(data['selling_price']>= 8150000) & (data['selling_price']<=8900000)]
# Out:
#                                                    name  selling_price  \
# 89    Mercedes-Benz S-Class S 350d Connoisseurs Edition        8150000
# 3872           Audi RS7 2015-2019 Sportback Performance        8900000
#
#       km_driven    fuel seller_type transmission        owner  Age
# 89         6500  Diesel      Dealer    Automatic  First Owner    7
# 3872      13000  Petrol      Dealer    Automatic  First Owner    8

# %%
data.shape
# Out:
# (4340, 8)

# %%
data.head(3)
# Out:
#                        name  selling_price  km_driven    fuel seller_type  \
# 0             Maruti 800 AC          60000      70000  Petrol  Individual
# 1  Maruti Wagon R LXI Minor         135000      50000  Petrol  Individual
# 2      Hyundai Verna 1.6 SX         600000     100000  Diesel  Individual
#
#   transmission        owner  Age
# 0       Manual  First Owner   17
# 1       Manual  First Owner   17
# 2       Manual  First Owner   12

# %% [markdown]
# 11) Encoding the Categorical Columns

# %%
data['fuel'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
data['fuel'] = data['fuel'].map({'Diesel':0,'CNG':1,'LPG':2 ,'Electric':3 ,'Petrol':4})

# %%
data['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
data['seller_type'] = data['seller_type'].map({'Individual':0,'Dealer':1,'Trustmark Dealer':2 })

# %%
data['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
data['transmission'] = data['transmission'].map({'Manual':0,'Automatic':1})

# %%
data['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Fourth & Above Owner',
#        'Third Owner', 'Test Drive Car'], dtype=object)

# %%
data['owner'] = data['owner'].map({'First Owner':0,'Second Owner':1,'Third Owner':2 ,'Fourth & Above Owner':3,'Test Drive Car':4})

# %%
data.head(3)
# Out:
#                        name  selling_price  km_driven  fuel  seller_type  \
# 0             Maruti 800 AC          60000      70000     4            0
# 1  Maruti Wagon R LXI Minor         135000      50000     4            0
# 2      Hyundai Verna 1.6 SX         600000     100000     0            0
#
#    transmission  owner  Age
# 0             0      0   17
# 1             0      0   17
# 2             0      0   12

# %% [markdown]
# 12) Store Feature Matrix In X and Response In Vector y

# %%
X = data.drop(['name','selling_price'],axis=1)
Y = data['selling_price']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9ad83ea349cc> in <cell line: 1>()
# ----> 1 X = data.drop(['name','selling_price'],axis=1)
#       2 Y = data['selling_price']
#
# NameError: name 'data' is not defined

# %%
X
# Out:
#       km_driven  fuel  seller_type  transmission  owner  Age
# 0         70000     4            0             0      0   17
# 1         50000     4            0             0      0   17
# 2        100000     0            0             0      0   12
# 3         46000     4            0             0      0    7
# 4        141000     0            0             0      1   10
# ...         ...   ...          ...           ...    ...  ...
# 4335      80000     0            0             0      1   10
# 4336      80000     0            0             0      1   10
# 4337      83000     4            0             0      1   15
# 4338      90000     0            0             0      0    8
# 4339      40000     4            0             0      0    8
#
# [4340 rows x 6 columns]

# %%
Y
# Out:
# 0        60000
# 1       135000
# 2       600000
# 3       250000
# 4       450000
#          ...
# 4335    409999
# 4336    409999
# 4337    110000
# 4338    865000
# 4339    225000
# Name: selling_price, Length: 4340, dtype: int64

# %% [markdown]
# 13) Splitting The Dataset Into The Training Set And Test Set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-436a975d142b> in <cell line: 1>()
# ----> 1 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)
#
# NameError: name 'y' is not defined

# %% [markdown]
# 14) Import The models

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
X_train = X_train.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-206d24119c5e> in <cell line: 1>()
# ----> 1 X_train = X_train.dropna()
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# 15) Model Training

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)

rf = RandomForestRegressor()
rf.fit(X_train,y_train)

xgb = GradientBoostingRegressor()
xgb.fit(X_train,y_train)

xg = XGBRegressor()
xg.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-03d40e6de659> in <cell line: 2>()
#       1 lr = LinearRegression()
# ----> 2 lr.fit(X_train,y_train)
#       3
#       4 rf = RandomForestRegressor()
#       5 rf.fit(X_train,y_train)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# 16) Prediction on Test Data

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = rf.predict(X_test)
y_pred3 = xgb.predict(X_test)
y_pred4 = xg.predict(X_test)

# %% [markdown]
# 17) Evaluating the Algorithm

# %%
from sklearn import metrics

# %%
score1 = metrics.r2_score(y_test,y_pred1)
score2 = metrics.r2_score(y_test,y_pred2)
score3 = metrics.r2_score(y_test,y_pred3)
score4 = metrics.r2_score(y_test,y_pred4)

# %%
print(score1,score2,score3,score4)
# Out:
# 0.3990069432558716 0.5023776657768022 0.4581304699745994 0.4947453781219847

# %%
final_data = pd.DataFrame({'Models':['LR','RF','GBR','XG'],
             "R2_SCORE":[score1,score2,score3,score4]})

# %%
final_data
# Out:
#   Models  R2_SCORE
# 0     LR  0.399007
# 1     RF  0.502378
# 2    GBR  0.458130
# 3     XG  0.494745

# %%
sns.barplot(x=final_data['Models'], y=final_data['R2_SCORE'])
# Out:
# <Axes: xlabel='Models', ylabel='R2_SCORE'>

# %% [markdown]
# 18) Save The Model

# %%
rf = RandomForestRegressor()
rf_final = rf.fit(X,y)

# %%
joblib.dump(rf_final,'car_price_prediction')
# Out:
# ['car_price_prediction']

# %%
model = joblib.load('car_price_prediction')

# %% [markdown]
# 19) Prediction on New Data

# %%
data_new = pd.DataFrame({
    'km_driven':98000,
    'fuel':2,
    'seller_type':0,
    'transmission':1,
    'owner':0,
    'Age':5
},index=[0])

# %% [markdown]
# 20) Predicated answer

# %%
result = model.predict(data_new)
rounded_result = round(result[0], 2)
print("Car Purchase amount:", rounded_result)
# Out:
# Car Purchase amount: 2201200.0

# %%
from sklearn.datasets import make_blobs
from sklearn.neighbors import KNeighborsClassifier
X, y = make_blobs(n_samples = 500, n_features = 2, centers = 4,cluster_std = 1.5, random_state = 4)
plt.style.use('seaborn')
plt.figure(figsize = (20,10))
plt.scatter(X[:,0], X[:,1], c=y, marker= '+',s=100,edgecolors='black')
plt.show()
knn5 = KNeighborsClassifier(n_neighbors = 5)
knn1 = KNeighborsClassifier(n_neighbors=1)
knn5.fit(X_train, y_train)
knn1.fit(X_train, y_train)

y_pred_5 = knn5.predict(X_test)
y_pred_1 = knn1.predict(X_test)
from sklearn.metrics import accuracy_score
print("Accuracy with k=5", accuracy_score(y_test, y_pred_5)*100)
print("Accuracy with k=1", accuracy_score(y_test, y_pred_1)*100)
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
plt.scatter(X_test[:,0], X_test[:,1], c=y_pred_5, marker= '+', s=100,edgecolors='black')
plt.title("Predicted values with k=5", fontsize=20)

plt.subplot(1,2,2)
plt.scatter(X_test[:,0], X_test[:,1], c=y_pred_1, marker= '+', s=100,edgecolors='black')
plt.title("Predicted values with k=1", fontsize=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-414ce4d8922b> in <cell line: 10>()
#       8 knn5 = KNeighborsClassifier(n_neighbors = 5)
#       9 knn1 = KNeighborsClassifier(n_neighbors=1)
# ---> 10 knn5.fit(X_train, y_train)
#      11 knn1.fit(X_train, y_train)
#      12
#
# NameError: name 'X_train' is not defined
